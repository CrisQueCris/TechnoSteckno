# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# Notes:
# doc overview: https://developer.spotify.com/documentation/web-api/
# doc
# url: https://api.spotify.com
# spotipy: https://spotipy.readthedocs.io/en/2.19.0/

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import config
import pandas as pd
from time import sleep
from random import randint

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id, client_secret=config.client_secret))

# %% [markdown]
# Approach:
# Get audio features of Billboard top 100
#
# - load csv
# - search track
# - save audio features

# %%
from CheckHotNot import load_billboard_csv

billboard10 =  load_billboard_csv()

# %%
billboard10
# Out:
#     Unnamed: 0  position                                          interpret  \
# 0            0         1  Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...
# 1            1         2                             Nicki Minaj X Lil Baby
# 2            2         3                                              Adele
# 3            3         4                                      Glass Animals
# 4            4         5                      The Kid LAROI & Justin Bieber
# ..         ...       ...                                                ...
# 95          95        96                                         Lucky Daye
# 96          96        97        Pusha T Featuring JAY-Z & Pharrell Williams
# 97          97        98                  Rauw Alejandro & Chencho Corleone
# 98          98        99                           Daddy Yankee & Bad Bunny
# 99          99       100                     BRELAND Featuring Thomas Rhett
#
#                         title  \
# ...

# %%
"""for url in urls:
    response = requests.get(url)
    if ( response.status_code == 200 ):
        print("Webpage successfully retrieved!")
        #scrape_website()
        seconds_to_wait = randint(2,7)
        print("Wating {} seconds before scraping the next website!".format(seconds_to_wait))
        sleep(seconds_to_wait)
    else:
        print("Unable to get the html code. Jumping to the next website")
"""

# %%
## Building a dataframe of spotify top 100 last 10 weeks track id and popularity

result={'artist': None,'id':None,'title':None,'popularity':None}
spot_pop = pd.DataFrame(columns=result)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16728\2009387997.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   spotpop = spot_pop.append(result, ignore_index=True)

# %%
## Only Get track id:

for title in list(billboard10['title']):
    print(title)
    if billboard10.loc[billboard10['title']==title, 'id'].index[0] == 0:
        result_search = sp.search(q=title[0:10], limit=1, market='GB')
        result['id']= result_search["tracks"]["items"][0]["id"] # Track ID
        print(result['id'])
        billboard10.loc[billboard10['title']==title, 'id']=result['id']
        seconds_to_wait = randint(1,3)
        seconds_to_wait
        sleep(seconds_to_wait)
# Out:
# We Don't Talk About Bruno
# 52xJxFP6TqMuO4Yt0eOkMz
# Do We Have A Problem?
# Easy On Me
# Heat Waves
# Stay
# Super Gremlin
# abcdefu
# Shivers
# Ghost
# Surface Pressure
# Pushin P
# Thats What I Want
# Need To Know
# Cold Heart (PNAU Remix)
# Bad Habits
# Industry Baby
# Levitating
# Save Your Tears
# Hrs And Hrs
# The Family Madrigal
# One Right Now
# Smokin Out The Window
# Oh My God
# I Hate U
# Good 4 U
# Love Nwantiti (Ah Ah Ah)
# Knife Talk
# Big Energy
# Woman
# You Should Probably Leave
# Enemy
# Better Days
# What Else Can I Do?
# Fingers Crossed
# Buy Dirt
# Fancy Like
# You Right
# Sand In My Boots
# Meet Me At Our Spot
# Don't Play That
# Dos Oruguitas
# Essence
# Cigarettes
# Kiss Me More
# Freedom Was A Highway
# Sacrifice
# 'Til You Can't
# To Be Loved By You
# Light Switch
# Thinking 'Bout You
# One Mississippi
# She's All I Wanna Be
# Waiting On A Miracle
# Half Of My Hometown
# P Power
# Heart On Fire
# Beers On Me
# 23
# AA
# Broadway Girls
# Chosen
# Doin' This
# ...

# %%
billboard10['id'].value_counts()
# Out:
# 0                         987
# 52xJxFP6TqMuO4Yt0eOkMz     10
# 4LRPiXqCikLlN15c3yImP7      2
# 1rDQ4oMwGJI7B4tovsBOxc      1
# Name: id, dtype: int64
